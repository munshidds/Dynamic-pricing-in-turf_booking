# %% [markdown]
# <a href="https://colab.research.google.com/github/munshidds/Dynamic-pricing-in-turf_booking/blob/main/dynamic_pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
times = ["Morning", "Afternoon", "Evening"]
customer_levels = ["Regular", "Premium", "Rare"]
temperatures = range(20, 40)
turf_ratings = range(1, 6)
discount_rates = [0.0, 0.05, 0.08, 0.1, 0.12, 0.15, 0.2]
weather_condition =['Partly Cloudy', 'Mostly Cloudy', 'T-Storms', 'Scattered T-Storms']


# Generate 4000 records
records = []
for _ in range(4000):
    record = {
        "day": random.choice(days),
        "time": random.choice(times),
        "customer_level": random.choice(customer_levels),
        "temperature": random.choice(temperatures),
        "turf_rating": random.choice(turf_ratings),
        "discount_rate": random.choice(discount_rates),
        "weather_condition":random.choice(weather_condition)
    }
    records.append(record)

df = pd.DataFrame(records).drop(['discount_rate'],axis=1)

df.to_csv("turf_booking_data.csv", index=False)

# %%
data=pd.read_csv('turf_booking_data.csv')
data
# Out:
#             day       time customer_level  temperature  turf_rating  \
# 0        Monday    Evening        Regular           33            2
# 1        Monday  Afternoon        Premium           20            5
# 2      Saturday    Evening        Premium           21            4
# 3     Wednesday    Evening           Rare           33            4
# 4        Sunday    Morning        Regular           22            1
# ...         ...        ...            ...          ...          ...
# 3995   Thursday    Evening           Rare           27            2
# 3996  Wednesday    Morning           Rare           34            4
# 3997    Tuesday    Evening           Rare           25            2
# 3998     Sunday    Morning        Regular           36            3
# 3999    Tuesday    Evening        Regular           32            1
#
#        weather_condition
# 0          Partly Cloudy
# 1          Mostly Cloudy
# 2     Scattered T-Storms
# 3          Mostly Cloudy
# ...

# %%
replace_dic={'day' :{"Monday":2, "Tuesday":2, "Wednesday":2, "Thursday":2, "Friday":1, "Saturday":0, "Sunday":0},
'time':{"Morning":1, "Afternoon":2, "Evening":0},
'customer_level':{"Regular":1, "Premium":2, "Rare":0},
'turf_rating' :{1:5,2:4,4:2,5:1},
'weather_condition':{'Partly Cloudy':0, 'Mostly Cloudy':0, 'T-Storms':1, 'Scattered T-Storms':1}}


new_data=data.replace(replace_dic)

new_data["temperature"]=data["temperature"].apply(lambda x: 0 if x > 35  else 1)
new_data['turf_rating']=new_data['turf_rating']/new_data['turf_rating'].max()

# %%
 new_data['total']=new_data.sum(axis=1)

# %%
new_data
# Out:
#       day  time  customer_level  temperature  turf_rating  weather_condition  \
# 0       2     0               1            1          0.8                  0
# 1       2     2               2            1          0.2                  0
# 2       0     0               2            1          0.4                  1
# 3       2     0               0            1          0.4                  0
# 4       0     1               1            1          1.0                  1
# ...   ...   ...             ...          ...          ...                ...
# 3995    2     0               0            1          0.8                  0
# 3996    2     1               0            1          0.4                  0
# 3997    2     0               0            1          0.8                  1
# 3998    0     1               1            0          0.6                  1
# 3999    2     0               1            1          1.0                  1
#
#       total
# 0       4.8
# 1       7.2
# ...

# %%
new_data[new_data['total'] == 8]
# Out:
#       day  time  customer_level  temperature  turf_rating  weather_condition  \
# 16      2     1               2            1          1.0                  1
# 101     2     1               2            1          1.0                  1
# 136     2     1               2            1          1.0                  1
# 155     2     2               1            1          1.0                  1
# 306     2     2               1            1          1.0                  1
# ...   ...   ...             ...          ...          ...                ...
# 3760    2     1               2            1          1.0                  1
# 3761    2     1               2            1          1.0                  1
# 3764    2     2               1            1          1.0                  1
# 3940    2     1               2            1          1.0                  1
# 3970    2     2               1            1          1.0                  1
#
#       total
# 16      8.0
# 101     8.0
# ...

# %%
new_data['total'].unique().max()
# Out:
# 9.0

# %%
# sorted(new_data['total'].unique())

# %%
import random

# random_values = [random.uniform(0, 0.02) for _ in range(10)]
# # discout=[]



# import numpy as np
# # result = ["even" if x % 2 == 0 else "odd" if x > 0 else "negative" for x in range(-5, 6)]
# np.array(random_values)*1000

# %%
discount = [
    random.uniform(0, 0.01) if x <= 1
    else random.uniform(0.01, 0.02) if x <=2
    else random.uniform(0.02, 0.03) if x <=3
    else random.uniform(0.03, 0.04) if x <=4

    else random.uniform(0.04, 0.05) if x <=5
    else random.uniform(0.05, 0.06) if x <=6

    else random.uniform(0.06, 0.07) if x <=7
    else random.uniform(0.07, 0.08) if x < 8

    else random.uniform(0.08, 0.16) for x in new_data['total']
]

# discount = [
#     0.01 if x <= 2
#     else .02 if 2 < x <= 4
#     else .05 if 4 < x <= 6
#     else .13 for x in new_data['total']
# ]

# %%
len(discount)
# Out:
# 4000

# %%
new_data['discount']=discount
new_data
# Out:
#       day  time  customer_level  temperature  turf_rating  weather_condition  \
# 0       2     0               1            1          0.8                  0
# 1       2     2               2            1          0.2                  0
# 2       0     0               2            1          0.4                  1
# 3       2     0               0            1          0.4                  0
# 4       0     1               1            1          1.0                  1
# ...   ...   ...             ...          ...          ...                ...
# 3995    2     0               0            1          0.8                  0
# 3996    2     1               0            1          0.4                  0
# 3997    2     0               0            1          0.8                  1
# 3998    0     1               1            0          0.6                  1
# 3999    2     0               1            1          1.0                  1
#
#       total  discount
# ...

# %%
round(new_data[new_data['total']==8]['discount']*1000)
# Out:
# 16      145.0
# 101      96.0
# 136     106.0
# 155      99.0
# 306     119.0
#         ...
# 3760    112.0
# 3761     90.0
# 3764    141.0
# 3940     88.0
# 3970    104.0
# Name: discount, Length: 68, dtype: float64

# %%
turf_tate=1000
new_data['final price']=round(new_data['discount']*turf_tate)
new_data
# Out:
#       day  time  customer_level  temperature  turf_rating  weather_condition  \
# 0       2     0               1            1          0.8                  0
# 1       2     2               2            1          0.2                  0
# 2       0     0               2            1          0.4                  1
# 3       2     0               0            1          0.4                  0
# 4       0     1               1            1          1.0                  1
# ...   ...   ...             ...          ...          ...                ...
# 3995    2     0               0            1          0.8                  0
# 3996    2     1               0            1          0.4                  0
# 3997    2     0               0            1          0.8                  1
# 3998    0     1               1            0          0.6                  1
# 3999    2     0               1            1          1.0                  1
#
#       total  discount  final price
# ...

# %%
data['final price']=new_data['final price']
data
# Out:
#             day       time customer_level  temperature  turf_rating  \
# 0        Monday    Evening        Regular           33            2
# 1        Monday  Afternoon        Premium           20            5
# 2      Saturday    Evening        Premium           21            4
# 3     Wednesday    Evening           Rare           33            4
# 4        Sunday    Morning        Regular           22            1
# ...         ...        ...            ...          ...          ...
# 3995   Thursday    Evening           Rare           27            2
# 3996  Wednesday    Morning           Rare           34            4
# 3997    Tuesday    Evening           Rare           25            2
# 3998     Sunday    Morning        Regular           36            3
# 3999    Tuesday    Evening        Regular           32            1
#
#        weather_condition  final price
# 0          Partly Cloudy         50.0
# 1          Mostly Cloudy         76.0
# ...

# %%
data.to_csv("turf_booking_data_final.csv", index=False)

# %%
data.corr()
# Out:
# <ipython-input-805-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              temperature  turf_rating  final price
# temperature     1.000000     0.007816    -0.164049
# turf_rating     0.007816     1.000000    -0.067973
# final price    -0.164049    -0.067973     1.000000

# %% [markdown]
# training model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data['discount']=new_data['discount']
data
# Out:
#             day       time customer_level  temperature  turf_rating  \
# 0        Monday    Evening        Regular           33            2
# 1        Monday  Afternoon        Premium           20            5
# 2      Saturday    Evening        Premium           21            4
# 3     Wednesday    Evening           Rare           33            4
# 4        Sunday    Morning        Regular           22            1
# ...         ...        ...            ...          ...          ...
# 3995   Thursday    Evening           Rare           27            2
# 3996  Wednesday    Morning           Rare           34            4
# 3997    Tuesday    Evening           Rare           25            2
# 3998     Sunday    Morning        Regular           36            3
# 3999    Tuesday    Evening        Regular           32            1
#
#        weather_condition  final price  discount
# 0          Partly Cloudy         50.0  0.049868
# 1          Mostly Cloudy         76.0  0.075718
# ...

# %%
replace_dic={'day' :{"Monday":2, "Tuesday":2, "Wednesday":2, "Thursday":2, "Friday":1, "Saturday":0, "Sunday":0},
'time':{"Morning":1, "Afternoon":2, "Evening":0},
'customer_level':{"Regular":1, "Premium":2, "Rare":0},
'weather_condition':{'Partly Cloudy':0, 'Mostly Cloudy':0, 'T-Storms':1, 'Scattered T-Storms':1}}


data=data.replace(replace_dic)

# %%
data
# Out:
#       day  time  customer_level  temperature  turf_rating  weather_condition  \
# 0       2     0               1           33            2                  0
# 1       2     2               2           20            5                  0
# 2       0     0               2           21            4                  1
# 3       2     0               0           33            4                  0
# 4       0     1               1           22            1                  1
# ...   ...   ...             ...          ...          ...                ...
# 3995    2     0               0           27            2                  0
# 3996    2     1               0           34            4                  0
# 3997    2     0               0           25            2                  1
# 3998    0     1               1           36            3                  1
# 3999    2     0               1           32            1                  1
#
#       final price  discount
# ...

# %%
data.corr()
# Out:
#                         day      time  customer_level  temperature  \
# day                1.000000 -0.024779       -0.017059    -0.009994
# time              -0.024779  1.000000        0.022779    -0.009606
# customer_level    -0.017059  0.022779        1.000000     0.015889
# temperature       -0.009994 -0.009606        0.015889     1.000000
# turf_rating       -0.013175 -0.013593       -0.013079     0.007816
# weather_condition -0.001449 -0.008380        0.000103    -0.019338
# final price        0.456622  0.474295        0.465943    -0.164049
# discount           0.456465  0.474757        0.465895    -0.163842
#
#                    turf_rating  weather_condition  final price  discount
# day                  -0.013175          -0.001449     0.456622  0.456465
# time                 -0.013593          -0.008380     0.474295  0.474757
# customer_level       -0.013079           0.000103     0.465943  0.465895
# ...

# %%
data
# Out:
#       day  time  customer_level  temperature  turf_rating  weather_condition  \
# 0       2     0               1           33            2                  0
# 1       2     2               2           20            5                  0
# 2       0     0               2           21            4                  1
# 3       2     0               0           33            4                  0
# 4       0     1               1           22            1                  1
# ...   ...   ...             ...          ...          ...                ...
# 3995    2     0               0           27            2                  0
# 3996    2     1               0           34            4                  0
# 3997    2     0               0           25            2                  1
# 3998    0     1               1           36            3                  1
# 3999    2     0               1           32            1                  1
#
#       final price  discount
# ...

# %%
X=data.drop(['final price',"discount"],axis=1)
y=data.discount
scaler=MinMaxScaler()
X=scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# model=LinearRegression()
model=DecisionTreeRegressor()
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 6.522735355031258e-05
# R^2 Score: 0.8667604804832111

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model=RandomForestRegressor()
rf_model.fit(X_train,y_train)
y_pred = rf_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 4.8798551159376435e-05
# R^2 Score: 0.9003194954923999

# %%
y_pred
# Out:
# array([0.0149967 , 0.04517786, 0.05182895, ..., 0.04352541, 0.03645298,
#        0.03351887])

# %%
data.head(1)
# Out:
#    day  time  customer_level  temperature  turf_rating  weather_condition  \
# 0    2     0               1           33            2                  0
#
#    final price  discount
# 0         50.0  0.049868

# %%
int(rf_model.predict(scaler.transform([[2,2,2,28,1,1]]))*1000)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 131

# %%
replace_dic={'day' :{"Monday":2, "Tuesday":2, "Wednesday":2, "Thursday":2, "Friday":1, "Saturday":0, "Sunday":0},
'time':{"Morning":1, "Afternoon":2, "Evening":0},
'customer_level':{"Regular":1, "Premium":2, "Rare":0},
'weather_condition':{'Partly Cloudy':0, 'Mostly Cloudy':0, 'T-Storms':1, 'Scattered T-Storms':1}}

# %%
data[data['final price']>100]
# Out:
#       day  time  customer_level  temperature  turf_rating  weather_condition  \
# 16      2     1               2           29            1                  1
# 19      2     2               2           31            5                  1
# 20      2     2               2           33            2                  1
# 38      2     2               2           34            5                  1
# 60      2     2               2           25            3                  1
# ...   ...   ...             ...          ...          ...                ...
# 3823    2     2               2           22            1                  1
# 3933    2     2               2           22            4                  1
# 3966    2     2               2           32            1                  1
# 3970    2     2               1           24            1                  1
# 3983    2     2               2           26            4                  1
#
#       final price  discount
# ...

# %%
import joblib
joblib.dump(rf_model,"dynamic_pricing_model")
# Out:
# ['dynamic_pricing_model']
